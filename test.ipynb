# %%
import tushare as ts
ts.set_token('854634d420c0b6aea2907030279da881519909692cf56e6f35c4718c')
# #  初始化pro接口
pro = ts.pro_api()
import pandas as pd

# %%
df = pd.read_parquet('data/trade/stock/20230928.parquet')

# %%
df
# Out:
#         code  high_x  low_x  open_x  close  pre_close_x  change_x      vol_x  \
# 0     301558   21.50  18.88   20.20  18.95         7.33    158.53   862049.0
# 1     300968   10.79   9.07    9.08  10.79         8.99     20.02   402965.0
# 2     300545   29.38  24.55   24.55  29.38        24.48     20.02   205077.0
# 3     301225   40.57  33.89   33.89  40.57        33.81     19.99   122316.0
# 4     300322    9.44   7.91    7.91   9.44         7.87     19.95   581881.0
# ...      ...     ...    ...     ...    ...          ...       ...        ...
# 5276  688320   44.29  39.93   44.10  40.00        44.10     -9.30    97927.0
# 5277  603895   26.26  26.26   26.26  26.26        29.18    -10.01    23160.0
# 5278  002691    9.08   7.54    8.73   7.54         8.38    -10.02   758287.0
# 5279  002406    8.12   7.62    8.00   7.62         8.47    -10.04  1707257.0
# 5280  301520   83.38  74.60   82.78  75.02        88.00    -14.75    93271.0
#
# ...

# %%
df.rename(columns={"close_x":"close"}, inplace=True)

# %%
df.to_parquet('data/trade/stock/20230928.parquet')

# %%
pro.fina_indicator_vip()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# e:\Z-自己研究\dekang-quant\test.ipynb 单元格 2 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Z-%E8%87%AA%E5%B7%B1%E7%A0%94%E7%A9%B6/dekang-quant/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> pro.fina_indicator_vip()
#
# File d:\anaconda3\envs\rl_env\lib\site-packages\tushare\pro\client.py:45, in DataApi.query(self, api_name, fields, **kwargs)
#      43 result = json.loads(res.text)
#      44 if result['code'] != 0:
# ---> 45     raise Exception(result['msg'])
#      46 data = result['data']
#      47 columns = data['fields']
#
# Exception: 抱歉，您没有访问该接口的权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
